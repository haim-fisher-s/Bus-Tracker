# %%
import os.path
import pickle
import re
import json
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aiah2'

# %%
# כאןן תשנו למסלול של קבצי CSV 
os.chdir(r"C:\Users\aiah2\Downloads\Python\Project\VMs_outputs_2")

# %%
frames = []

for i in range(1,7):
    df_i = pd.read_csv(f'2_{i}'+'.csv', encoding="utf-8")
    frames.append(df_i)
    
data = pd.concat(frames)
# Out:
# C:\Users\aiah2\AppData\Local\Temp\ipykernel_5832\2891245287.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_i = pd.read_csv(f'2_{i}'+'.csv', encoding="utf-8")
# C:\Users\aiah2\AppData\Local\Temp\ipykernel_5832\2891245287.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_i = pd.read_csv(f'2_{i}'+'.csv', encoding="utf-8")
# C:\Users\aiah2\AppData\Local\Temp\ipykernel_5832\2891245287.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_i = pd.read_csv(f'2_{i}'+'.csv', encoding="utf-8")
# C:\Users\aiah2\AppData\Local\Temp\ipykernel_5832\2891245287.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_i = pd.read_csv(f'2_{i}'+'.csv', encoding="utf-8")
# ...

# %%
data.shape
# Out:
# (4552195, 14)

# %%
data
# Out:
#         Unnamed: 0    TripId  OPERATOR_ID  CLUSTER_ID LINE_SHORT_NAME  \
# 0                0   1382474            3          91             106
# 1                1   1382474            3          91             106
# 2                2   1382474            3          91             106
# 3                3   1382474            3          91             106
# 4                4   1382474            3          91             106
# ...            ...       ...          ...         ...             ...
# 727964      727964  23207034            3          91              15
# 727965      727965  23207034            3          91              15
# 727966      727966  23207034            3          91              15
# 727967      727967  23207034            3          91              15
# 727968      727968  23207034            3          91              15
#
#        OriginAimedDepartureTime       ID  stopOrder    actualArrivalTime  \
# ...
